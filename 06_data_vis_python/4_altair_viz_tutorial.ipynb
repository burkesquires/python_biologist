# %% [markdown]
# # Visualizing with the `Altair`
# ***

# %%
# !pip install altair
# Out:
# Requirement already satisfied: altair in /Users/squiresrb/anaconda/lib/python3.6/site-packages
# Requirement already satisfied: traitlets>=4.3.1 in /Users/squiresrb/anaconda/lib/python3.6/site-packages (from altair)
# Requirement already satisfied: ipython in /Users/squiresrb/anaconda/lib/python3.6/site-packages (from altair)
# Requirement already satisfied: pandas in /Users/squiresrb/anaconda/lib/python3.6/site-packages (from altair)
# Requirement already satisfied: vega>=0.4.4 in /Users/squiresrb/anaconda/lib/python3.6/site-packages (from altair)
# Requirement already satisfied: python-dateutil>=2 in /Users/squiresrb/anaconda/lib/python3.6/site-packages (from pandas->altair)
# Requirement already satisfied: pytz>=2011k in /Users/squiresrb/anaconda/lib/python3.6/site-packages (from pandas->altair)
# Requirement already satisfied: numpy>=1.7.0 in /Users/squiresrb/anaconda/lib/python3.6/site-packages (from pandas->altair)
# Requirement already satisfied: six>=1.5 in /Users/squiresrb/anaconda/lib/python3.6/site-packages (from python-dateutil>=2->pandas->altair)

# %%
# !pip install --upgrade notebook  # need jupyter_client >= 4.2 for sys-prefix below
# Out:
# Collecting notebook
#   Downloading notebook-4.4.1-py2.py3-none-any.whl (6.9MB)
#     100% |████████████████████████████████| 6.9MB 72kB/s eta 0:00:011
# Requirement already up-to-date: tornado>=4 in /Users/squiresrb/anaconda/lib/python3.6/site-packages (from notebook)
# Collecting nbconvert (from notebook)
#   Downloading nbconvert-5.1.1-py2.py3-none-any.whl (372kB)
#     100% |████████████████████████████████| 378kB 1.1MB/s ta 0:00:011
# Requirement already up-to-date: ipython-genutils in /Users/squiresrb/anaconda/lib/python3.6/site-packages (from notebook)
# Collecting nbformat (from notebook)
#   Downloading nbformat-4.3.0-py2.py3-none-any.whl (154kB)
#     100% |████████████████████████████████| 163kB 2.6MB/s eta 0:00:01
# Collecting jinja2 (from notebook)
#   Downloading Jinja2-2.9.5-py2.py3-none-any.whl (340kB)
#     100% |████████████████████████████████| 348kB 1.8MB/s ta 0:00:011
# Collecting jupyter-core (from notebook)
#   Downloading jupyter_core-4.3.0-py2.py3-none-any.whl (76kB)
#     100% |████████████████████████████████| 81kB 3.2MB/s eta 0:00:01
# Collecting jupyter-client (from notebook)
#   Downloading jupyter_client-5.0.0-py2.py3-none-any.whl (83kB)
#     100% |████████████████████████████████| 92kB 2.7MB/s ta 0:00:011
# Collecting traitlets (from notebook)
#   Downloading traitlets-4.3.2-py2.py3-none-any.whl (74kB)
#     100% |████████████████████████████████| 81kB 3.7MB/s eta 0:00:01
# Requirement already up-to-date: ipykernel in /Users/squiresrb/anaconda/lib/python3.6/site-packages (from notebook)
# Requirement already up-to-date: terminado>=0.3.3; sys_platform != "win32" in /Users/squiresrb/anaconda/lib/python3.6/site-packages (from notebook)
# Collecting testpath (from nbconvert->notebook)
#   Downloading testpath-0.3-py2.py3-none-any.whl (82kB)
#     100% |████████████████████████████████| 92kB 2.8MB/s ta 0:00:01
# Collecting bleach (from nbconvert->notebook)
#   Downloading bleach-1.5.0-py2.py3-none-any.whl
# Collecting entrypoints>=0.2.2 (from nbconvert->notebook)
#   Downloading entrypoints-0.2.2-py2.py3-none-any.whl
# Requirement already up-to-date: mistune!=0.6 in /Users/squiresrb/anaconda/lib/python3.6/site-packages (from nbconvert->notebook)
# Collecting pygments (from nbconvert->notebook)
#   Downloading Pygments-2.2.0-py2.py3-none-any.whl (841kB)
#     100% |████████████████████████████████| 849kB 530kB/s ta 0:00:011
# Collecting pandocfilters>=1.4.1 (from nbconvert->notebook)
#   Downloading pandocfilters-1.4.1.tar.gz
# Collecting jsonschema!=2.5.0,>=2.4 (from nbformat->notebook)
#   Downloading jsonschema-2.6.0-py2.py3-none-any.whl
# Requirement already up-to-date: MarkupSafe>=0.23 in /Users/squiresrb/anaconda/lib/python3.6/site-packages (from jinja2->notebook)
# Requirement already up-to-date: python-dateutil>=2.1 in /Users/squiresrb/anaconda/lib/python3.6/site-packages (from jupyter-client->notebook)
# Requirement already up-to-date: pyzmq>=13 in /Users/squiresrb/anaconda/lib/python3.6/site-packages (from jupyter-client->notebook)
# Requirement already up-to-date: decorator in /Users/squiresrb/anaconda/lib/python3.6/site-packages (from traitlets->notebook)
# Requirement already up-to-date: six in /Users/squiresrb/anaconda/lib/python3.6/site-packages (from traitlets->notebook)
# Collecting html5lib!=0.9999,!=0.99999,<0.99999999,>=0.999 (from bleach->nbconvert->notebook)
#   Downloading html5lib-0.9999999.tar.gz (889kB)
#     100% |████████████████████████████████| 890kB 525kB/s ta 0:00:011
# Building wheels for collected packages: pandocfilters, html5lib
# done
#   Stored in directory: /Users/squiresrb/Library/Caches/pip/wheels/d4/01/68/49055c80b9f01ccb49241e73c8019628605064730941d70b56
# done
#   Stored in directory: /Users/squiresrb/Library/Caches/pip/wheels/6f/85/6c/56b8e1292c6214c4eb73b9dda50f53e8e977bf65989373c962
# Successfully built pandocfilters html5lib
# Installing collected packages: traitlets, testpath, html5lib, bleach, jsonschema, jupyter-core, nbformat, entrypoints, jinja2, pygments, pandocfilters, nbconvert, jupyter-client, notebook
#   Found existing installation: traitlets 4.3.1
#     DEPRECATION: Uninstalling a distutils installed project (traitlets) has been deprecated and will be removed in a future version. This is due to the fact that uninstalling a distutils project will only partially uninstall the project.
#     Uninstalling traitlets-4.3.1:
#       Successfully uninstalled traitlets-4.3.1
#   Found existing installation: jsonschema 2.5.1
#     Uninstalling jsonschema-2.5.1:
#       Successfully uninstalled jsonschema-2.5.1
#   Found existing installation: jupyter-core 4.2.1
#     DEPRECATION: Uninstalling a distutils installed project (jupyter-core) has been deprecated and will be removed in a future version. This is due to the fact that uninstalling a distutils project will only partially uninstall the project.
#     Uninstalling jupyter-core-4.2.1:
#       Successfully uninstalled jupyter-core-4.2.1
#   Found existing installation: nbformat 4.2.0
#     DEPRECATION: Uninstalling a distutils installed project (nbformat) has been deprecated and will be removed in a future version. This is due to the fact that uninstalling a distutils project will only partially uninstall the project.
#     Uninstalling nbformat-4.2.0:
#       Successfully uninstalled nbformat-4.2.0
#   Found existing installation: Jinja2 2.9.4
#     Uninstalling Jinja2-2.9.4:
#       Successfully uninstalled Jinja2-2.9.4
#   Found existing installation: Pygments 2.1.3
#     Uninstalling Pygments-2.1.3:
#       Successfully uninstalled Pygments-2.1.3
#   Found existing installation: nbconvert 4.2.0
#     DEPRECATION: Uninstalling a distutils installed project (nbconvert) has been deprecated and will be removed in a future version. This is due to the fact that uninstalling a distutils project will only partially uninstall the project.
#     Uninstalling nbconvert-4.2.0:
#       Successfully uninstalled nbconvert-4.2.0
#   Found existing installation: jupyter-client 4.4.0
#     DEPRECATION: Uninstalling a distutils installed project (jupyter-client) has been deprecated and will be removed in a future version. This is due to the fact that uninstalling a distutils project will only partially uninstall the project.
#     Uninstalling jupyter-client-4.4.0:
#       Successfully uninstalled jupyter-client-4.4.0
#   Found existing installation: notebook 4.3.1
#     DEPRECATION: Uninstalling a distutils installed project (notebook) has been deprecated and will be removed in a future version. This is due to the fact that uninstalling a distutils project will only partially uninstall the project.
#     Uninstalling notebook-4.3.1:
#       Successfully uninstalled notebook-4.3.1
# Successfully installed bleach-1.5.0 entrypoints-0.2.2 html5lib-0.9999999 jinja2-2.9.5 jsonschema-2.6.0 jupyter-client-5.0.0 jupyter-core-4.3.0 nbconvert-5.1.1 nbformat-4.3.0 notebook-4.4.1 pandocfilters-1.4.1 pygments-2.2.0 testpath-0.3 traitlets-4.3.2

# %%
# !jupyter nbextension install --sys-prefix --py vega
# Out:
# Installing /Users/squiresrb/anaconda/lib/python3.6/site-packages/vega/static -> jupyter-vega
# Up to date: /Users/squiresrb/anaconda/share/jupyter/nbextensions/jupyter-vega/index.js
# Up to date: /Users/squiresrb/anaconda/share/jupyter/nbextensions/jupyter-vega/index.js.map
# Up to date: /Users/squiresrb/anaconda/share/jupyter/nbextensions/jupyter-vega/vega-lite.html
# Up to date: /Users/squiresrb/anaconda/share/jupyter/nbextensions/jupyter-vega/vega.html
# Up to date: /Users/squiresrb/anaconda/share/jupyter/nbextensions/jupyter-vega/vega.js
# - Validating: OK
#
#     To initialize this nbextension in the browser every time the notebook (or other app) loads:
#
#           jupyter nbextension enable vega --py --sys-prefix

# %%
# !jupyter nbextension enable vega --py --sys-prefix
# Out:
# Enabling notebook extension jupyter-vega/index...
#       - Validating: OK

# %%
from altair import tutorial
tutorial()
# Out:
# Copying notebooks into fresh tutorial directory: ./AltairTutorial
# Click on the following notebooks to explore the tutorial:
# ./AltairTutorial/
#   01-Index.ipynb
#   02-Introduction.ipynb
#   03-ScatterCharts.ipynb
#   04-BarCharts.ipynb
#   05-LineCharts.ipynb
#   06-AreaCharts.ipynb
#   07-LayeredCharts.ipynb
#   08-GroupedRegressionCharts.ipynb
#   09-CarsDataset.ipynb
#   10-Heatmaps.ipynb
#   12-Measles.ipynb
#   API.ipynb
#   example.html
#   Untitled.ipynb
# ./AltairTutorial/auto_examples/
#   area.ipynb
#   area_vertical.ipynb
#   bar_1d.ipynb
#   bar_1d_bandsize_config.ipynb
#   bar_aggregate.ipynb
#   bar_aggregate_size.ipynb
#   bar_aggregate_vertical.ipynb
#   bar_grouped.ipynb
#   bar_grouped_horizontal.ipynb
#   bar_layered_transparent.ipynb
#   bar_size_default.ipynb
#   bar_size_explicit.ipynb
#   bar_size_explicit_bad.ipynb
#   bar_size_fit.ipynb
#   bar_yearmonth.ipynb
#   box_plot.ipynb
#   bubble_health_income.ipynb
#   circle.ipynb
#   errorbar_aggregate.ipynb
#   errorbar_horizontal_aggregate.ipynb
#   github_punchcard.ipynb
#   histogram.ipynb
#   Index.ipynb
#   layer_histogram.ipynb
#   layer_line_color_rule.ipynb
#   line.ipynb
#   line_color.ipynb
#   line_detail.ipynb
#   line_monotone.ipynb
#   line_month.ipynb
#   line_quarter.ipynb
#   line_quarter_legend.ipynb
#   line_slope.ipynb
#   line_step.ipynb
#   overlay_area_full.ipynb
#   overlay_area_short.ipynb
#   overlay_line_full.ipynb
#   overlay_line_short.ipynb
#   point_1d.ipynb
#   point_dot_timeunit_color.ipynb
#   point_filled.ipynb
#   scatter.ipynb
#   scatter_aggregate_detail.ipynb
#   scatter_binned.ipynb
#   scatter_binned_color.ipynb
#   scatter_binned_size.ipynb
#   scatter_bubble.ipynb
#   scatter_color.ipynb
#   scatter_color_custom.ipynb
#   scatter_color_order.ipynb
#   scatter_color_ordinal.ipynb
#   scatter_color_ordinal_custom.ipynb
#   scatter_color_quantitative.ipynb
#   scatter_color_shape_constant.ipynb
#   scatter_colored_with_shape.ipynb
#   scatter_connected.ipynb
#   scatter_opacity.ipynb
#   scatter_shape_custom.ipynb
#   square.ipynb
#   stacked_area.ipynb
#   stacked_area_binned.ipynb
#   stacked_area_normalize.ipynb
#   stacked_area_ordinal.ipynb
#   stacked_area_stream.ipynb
#   stacked_bar_1d.ipynb
#   stacked_bar_h.ipynb
#   stacked_bar_h_order.ipynb
#   stacked_bar_normalize.ipynb
#   stacked_bar_population.ipynb
#   stacked_bar_size.ipynb
#   stacked_bar_sum_opacity.ipynb
#   stacked_bar_v.ipynb
#   stacked_bar_weather.ipynb
#   text_scatter_colored.ipynb
#   text_table_heatmap.ipynb
#   tick_dot.ipynb
#   tick_dot_thickness.ipynb
#   tick_strip.ipynb
#   trellis_anscombe.ipynb
#   trellis_bar.ipynb
#   trellis_bar_histogram.ipynb
#   trellis_barley.ipynb
#   trellis_row_column.ipynb
#   trellis_scatter.ipynb
#   trellis_scatter_binned_row.ipynb
#   trellis_stacked_bar.ipynb
