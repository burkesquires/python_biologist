# %% [markdown]
# # Heatmaps

# %% [markdown]
# A heatmap is a rectangular grid with the rectangles within the grid colored to visually encode a numerical value. Making a heatmap in Vega-Lite 1.0 is a bit subtle, so we show examples here.

# %% [markdown]
# ## Imports

# %%
import altair as alt
import pandas as pd

# %%
# Uncomment/run this line to enable Altair in JupyterLab/nteract:
# alt.enable_mime_rendering()

# %% [markdown]
# ## Load dataset

# %%
cars = alt.load_dataset('cars')

# %% [markdown]
# ## Default heatmap

# %%
alt.Chart(cars).mark_text().encode(
    alt.Color('mean(Miles_per_Gallon):Q', sort='descending'),
    column='Cylinders:O',
    text='mean(Miles_per_Gallon):Q',
    row='Origin'
)
# Out:
# <div class="vega-embed" id="4c126c71-5d23-4d14-a513-a0d7116b8db7"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Coloring background

# %%
alt.Chart(cars).mark_text(applyColorToBackground=True).encode(
    alt.Row('Origin:O'),
    alt.Column('Cylinders:O'),
    alt.Color('mean(Miles_per_Gallon):Q', sort='descending'),
    alt.Text('mean(Miles_per_Gallon):Q')
)
# Out:
# <div class="vega-embed" id="a4fc83b1-99c3-4ce3-b058-cfd1d56717e8"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Customizing colormap
# Vega-lite currently only supports colormaps between two colors.
#
# HTML color names can also be used (e.g., `'#d62728'`).

# %%
alt.Chart(cars).mark_text(applyColorToBackground=True).encode(
    alt.Row('Origin:O'),
    alt.Column('Cylinders:O'),
    alt.Color('mean(Miles_per_Gallon):Q', sort='descending', scale=alt.Scale(range=['pink', 'red'])),
    alt.Text(' '),
)
# Out:
# ---------------------------------------------------------------------------
# FieldError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     907             method = get_real_method(obj, self.print_method)
#     908             if method is not None:
# --> 909                 method()
#     910                 return True
#     911
#
# ~/anaconda3/lib/python3.6/site-packages/altair/v1/api.py in _ipython_display_(self)
#     443         from IPython.display import display
#     444         from vega import VegaLite
# --> 445         display(VegaLite(self.to_dict(validate_columns=True)))
#     446
#     447     def display(self):
#
# ~/anaconda3/lib/python3.6/site-packages/altair/v1/api.py in to_dict(self, data, validate_columns)
#     287             The JSON specification of the chart object.
#     288         """
# ...
