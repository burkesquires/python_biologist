# %% [markdown]
# # Jupyter Notebook – Enabling Collaborative, Reproducible Science for All

# %% [markdown]
# R. Burke Squires
#
# https://github.com/burkesquires

# %% [markdown]
# ---

# %% [markdown]
# ## In 2018, the _Atlantic_ magazine declared that...
#
#
# ![Screen%20Shot%202018-08-12%20at%202.48.01%20PM.png](attachment:Screen%20Shot%202018-08-12%20at%202.48.01%20PM.png)
#
# https://www.theatlantic.com/science/archive/2018/04/the-scientific-paper-is-obsolete/556676/

# %% [markdown]
# Scientific paper is essentially unchanged since it's creation in the 1600's.
#
# What are the major parts of a "standard" scientific paper??

# %% [markdown]
# BUT...
#
# _The Scientist_ published a paper entitled _The Death of the Scientific Paper_ is 2006!
#
# https://www.the-scientist.com/opinion-old/the-death-of-the-scientific-paper-47251

# %% [markdown]
# ## There are alternatives

# %% [markdown]
# ## 1988
#
# ### Wolfram Mathematica
#
# "Wolfram Mathematica (usually termed Mathematica) is a modern technical computing system spanning most areas of technical computing — including neural networks, machine learning, image processing, geometry, data science, visualizations, and others" Wikipedia
#
# Two parts:
# - the kernel - interprets expressions and returns results
# - the front end (notebook)

# %% [markdown]
# ### Mathematica Notebook
#
# http://www.wolfram.com/notebooks/
#
# - Designed by Theodore Gray in 1988
# - Provides a GUI, allows for creation and editing of notebooks
# - Notebooks contain
#     - program code
#     - formatted text
# - Results including
#     - typeset mathematics
#     - graphics
#     - GUI components
#     - tables
#     - sounds
#
# The notebook implements a form of _literate programming_ devised by Donald E. Knuth, an American Computer scientist; creator of Tex, predecessor of LaTeX
#
# As we will learn, this sounds a LOT like a Jupyter notebook!

# %% [markdown]
# ### __Why did Mathematica notebooks not take off__
#
# The _Atlantic_ article asks why Jupyter succeed where Mathematica failed.
#
# "The obvious contrast is between the proprietary world of Wolfram and the open-source model of the software ecosystem that Jupyter mobilizes." Romer
#
# - Wolfram is [commercial](https://www.wolfram.com/mathematica/pricing/government-individuals.php), Jupyter is open-source
# - Wolfram only supports a single language, Jupyter supports 40+ languages

# %% [markdown]
# ## 2001
#
# - IPython is created

# %% [markdown]
# ## 2011
#
# - ["Beyond the PDF"](https://sites.google.com/site/beyondthepdf/) workshop hosted by Phil Bourne
# - Jupyter notebook first created

# %% [markdown]
# ## 2014
#
# - Pat Schloss - Nature Microbiome ipython notebook as supplementary material

# %% [markdown]
# ## Today
#
# What is the status of Jupyter notebooks today?

# %% [markdown]
# #### Google Trends
#
# Jupyter notebooks
#
# https://trends.google.com/trends/explore?date=all&q=jupyter
#
# Comparison - Past 5 Years
#
# https://trends.google.com/trends/explore?date=today%205-y&q=jupyter,mathematica,r%20notebook,r%20markdown,rstudio
#
# Comparison - All years
#
# https://trends.google.com/trends/explore?date=all&q=jupyter,mathematica,r%20notebook,r%20markdown,rstudio
#
# What do we see in the graphs?
# What do you think causes the ups and downs in the mathematica?

# %% [markdown]
# ## How Do Jupter Notebooks Help Perform & Communicate Science?
#
# Jupyter Notebooks help perform and communicate science in many phases:
#
# - Experimental design phase
# - Grant writing phase
# - Analysis phase
# - Collaboration phase
# - Publication phase

# %% [markdown]
# ### Experimental Design Phase:
#
# - Beging writing narrative that will drive:
#     - Grant application
#     - Actual research
#     - A possible scientifi paper
# - Assist in preliminary data analysis
# - Keeps a record of all thoughts and steps in the process

# %% [markdown]
# ### Grant Writing Phase:
#
# - Take record of what was written
# - Clean it up
# - Use output from preliminary data analysis in application
# - Expand analysis if resubmitting grant

# %% [markdown]
# ### Grant received... :-)

# %% [markdown]
# ### Analysis Phase:
#
# - Jupyter notebook are a record of the though process and exploratory workflow
# - Using existing Notebook to communicate project to PostDoc or grad student who will do the work
# - Enables researcher to see preliminary data analysis and teh narative that surronds it
# - Combine existing tools and scripts into a single workflow
#
# - NOTE: I start by using a single notebook for my workflow, creating a new cell for each change or iteration of my analysis. Only after I am satisfied with the results of my analysis, do I duplicate my notebook and CAREFULLY delete cells, which are not part of the final workflow.

# %% [markdown]
# ### Collaboration Phase:
#
# - Sending a Jupyter notebook as a single document to a collaborator or to PI
# - They can rerun analysis, edit, remove or add to it (if they have teh software installed)

# %% [markdown]
# ### Communication Phase
#
# - Use the notebook as the start of a manuscript
# - Examples
#     - Reproducible Science Curriculum - [Publication](https://reproducible-science-curriculum.github.io/publication-RR-Jupyter/aio.html)
#     - [Jupyter notebook manuscript workflow](https://sylvaindeville.net/2015/07/17/writing-academic-papers-in-plain-text-with-markdown-and-jupyter-notebook/)
# - Sumbit notebook as suplementsry material
# - Future
#     - Submit notebook as actual manuscript?

# %% [markdown]
# ## Drivers of Jupyter Notebooks
#
# ### Reproducible Science
#
# Jupyter notebooks referenced in Pubmed Central:
#
# https://www.ncbi.nlm.nih.gov/pmc/?term=(%22.ipynb%22+OR+%22jupyter%22+OR+%22ipython+notebook%22)
#
# ### Data Science
#
# https://trends.google.com/trends/explore?date=today%205-y&q=data%20science,jupyter

# %% [markdown]
# ---

# %% [markdown]
# ### References
#
# 1. Somers, James. "The Scientific Paper Is Obsolete". The Atlantic. Retrieved 2018-04-10.
# 1. Romer, Paul. "Jupyter, Mathematica, and the Future of the Research Paper" https://paulromer.net/jupyter-mathematica-and-the-future-of-the-research-paper/
# 1. Victor, Brett. [Scientific Communication As Sequential Art](http://worrydream.com/ScientificCommunicationAsSequentialArt/). May 24, 2011
# 1. Randles BM, Pasquetto IV, JCDL MG, ACM 2, 2017. [_Using the Jupyter Notebook as a tool for open science: An empirical study._](https://arxiv.org/pdf/1804.05492.pdf)
# 1. https://sylvaindeville.net/2015/07/17/writing-academic-papers-in-plain-text-with-markdown-and-jupyter-notebook/

# %% [markdown]
# ---

# %%
# !jupyter nbconvert 0_Jupyter_training.ipynb --to slides --post serve --SlidesExporter.reveal_theme=simple
